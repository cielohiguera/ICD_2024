# %% [markdown]
# ## PART I

# %% [markdown]
# ### *Jupyter: Beyond Normal Python*

# %% [markdown]
# #### Chapter 1: Getting Started in IPython and Jupyter

# %% [markdown]
# ##### Alumno (a): Cielo Aholiva Higuera Gutiérrez

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %%
L = [1, 2, 3]
L.insert?
# Out:
# Signature: L.insert(index, object, /)
# Docstring: Insert object before index.
# Type:      builtin_function_or_method

# %%
L?
# Out:
# Type:        list
# String form: [1, 2, 3]
# Length:      3
# Docstring:
# Built-in mutable sequence.
#
# If no argument is given, the constructor creates a new empty list.
# The argument must be an iterable if specified.

# %%
def square (a): return a ** 2
# def test(square, a): return square(a)

# %%
square?
# Out:
# Signature: square(a)
# Docstring: <no docstring>
# File:      c:\users\cielo aholiva\appdata\local\temp\ipykernel_18988\884792827.py
# Type:      function

# %% [markdown]
# ##### Accessing Source Code with ??

# %%
square??
# Out:
# Signature: square(a)
# Docstring: <no docstring>
# Source:    def square (a): return a ** 2
# File:      c:\users\cielo aholiva\appdata\local\temp\ipykernel_18988\884792827.py
# Type:      function

# %%
len??
# Out:
# Signature: len(obj, /)
# Docstring: Return the number of items in a container.
# Type:      builtin_function_or_method

# %% [markdown]
# ##### Exploring Modules with Tab Completion

# %%
L.append
L.clear
L.copy
L.count
L.extend
L.index
L.insert
L.pop
# Out:
# <function list.pop(index=-1, /)>

# %%
L.clear
L.copy
# Out:
# <function list.copy()>

# %%
L.__add__
# Out:
# <method-wrapper '__add__' of list object at 0x0000021E2B08E380>

# %%
from itertools import chain

# %%
import heapdict

# %% [markdown]
# ##### Beyond tab completition: Wildcard matching

# %%
*Warning?
# Out:
# BytesWarning
# DeprecationWarning
# EncodingWarning
# FutureWarning
# ImportWarning
# PendingDeprecationWarning
# ResourceWarning
# RuntimeWarning
# SyntaxWarning
# UnicodeWarning
# UserWarning
# Warning

# %%
str.*find*?
# Out:
# str.find
# str.rfind

# %% [markdown]
# ##### Command History Shortcuts

# %%
def square (a): return a ** 2

# %%
square(2)
# Out:
# 4

# %% [markdown]
# #### Chapter 2: Enhanced Interactive Features

# %%
# %run myscript.ipynb

# %%
square(5)
# Out:
# 25

# %% [markdown]
# ##### Timing Code Execution: %timeit

# %%
# %timeit L = [n ** 2 for n in range(1000)]
# Out:
# 108 μs ± 6.09 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %%
# %%timeit
L = []
for n in range(1000):
    L.append(n**2)
# Out:
# 127 μs ± 6.3 μs per loop (mean ± std. dev. of 7 runs, 10,000 loops each)

# %% [markdown]
# ##### Help on Magig Fuctions:?, %magic, and %Ismagic

# %%
# %timeit

# %%
# %magic
# Out:
# IPython's 'magic' functions
# ...
#
# The magic function system provides a series of functions which allow you to
# control the behavior of IPython itself, plus a lot of system-type
# features. There are two kinds of magics, line-oriented and cell-oriented.
#
# Line magics are prefixed with the % character and work much like OS
# command-line calls: they get as an argument the rest of the line, where
# arguments are passed without parentheses or quotes.  For example, this will
# time the given statement::
#
#         %timeit range(1000)
#
# Cell magics are prefixed with a double %%, and they are functions that get as
# an argument not only the rest of the line, but also the lines below it in a
# separate argument.  These magics are called with two arguments: the rest of the
# call line and the body of the cell, consisting of the lines below the first.
# For example::
#
#         %%timeit x = numpy.random.randn((100, 100))
#         numpy.linalg.svd(x)
#
# ...

# %% [markdown]
# ##### IPython's In and Out Objects

# %%
import math

# %%
math.sin(2)
# Out:
# 0.9092974268256817

# %%
math.cos(2)
# Out:
# -0.4161468365471424

# %%
In = ['', math.sin(2), math.cos(2)]

# %%
In
# Out:
# ['', 0.9092974268256817, -0.4161468365471424]

# %%
Out  = ['', math.sin(2), math.cos(2)]

# %%
Out
# Out:
# ['', 0.9092974268256817, -0.4161468365471424]

# %%
print(In)
# Out:
# ['', 0.9092974268256817, -0.4161468365471424]

# %%
print(Out)
# Out:
# ['', 0.9092974268256817, -0.4161468365471424]

# %%
Out[1]**2 + Out[2]**2
# Out:
# 1.0

# %% [markdown]
# ##### Underscore Shortcuts and Previous Outputs

# %%
print(_)
# Out:
# [{"varName": "In", "varType": "list", "varSize": "80", "varShape": "3", "varContent": "['', 0.9092974268256817, -0.4161468365471424]", "isMatrix": true, "isWidget": false}, {"varName": "L", "varType": "list", "varSize": "88", "varShape": "3", "varContent": "[1, 2, 3]", "isMatrix": true, "isWidget": false}, {"varName": "Out", "varType": "list", "varSize": "80", "varShape": "3", "varContent": "['', 0.9092974268256817, -0.4161468365471424]", "isMatrix": true, "isWidget": false}, {"varName": "a", "varType": "int", "varSize": "28", "varShape": "", "varContent": "5", "isMatrix": false, "isWidget": false}, {"varName": "coseno", "varType": "float", "varSize": "24", "varShape": "", "varContent": "-0.4161468365471424", "isMatrix": false, "isWidget": false}, {"varName": "inputs", "varType": "list", "varSize": "104", "varShape": "5", "varContent": "['', 'import math', 'math.sin(2)', 'math.cos(2)', 'In']", "isMatrix": true, "isWidget": false}, {"varName": "out", "varType": "list", "varSize": "104
# ...

# %%
print(__)
# Out:
# {"dataframes": [], "user": "Cielo Aholiva"}

# %%
Out[1]
# Out:
# 0.9092974268256817

# %%
_1
# Out:
# '{"dataframes": [], "user": "Cielo Aholiva"}'

# %% [markdown]
# ##### Suppressing Output

# %%
math.sin(2) + math.cos(2)
# Out:
# 0.4931505902785393

# %%
446 in out
# Out:
# False

# %% [markdown]
# ##### Related Magic Commands

# %%
In [446] %history -n 1-3
import math
math.sin(2)
math.cos(2)
# Out:
#   Cell In[483], line 1
#     In [446] %history -n 1-3
#                          ^
# SyntaxError: invalid syntax

# %% [markdown]
# ##### Shell commands in IPython

# %%
# !echo "printing from the shell"
# Out:
# "printing from the shell"

# %%
contents = !ls

# %%
print(contents)
# Out:
# ['"ls" no se reconoce como un comando interno o externo,', 'programa o archivo por lotes ejecutable.']

# %%
directory = !pwd

# %%
print(directory)
# Out:
# ['"pwd" no se reconoce como un comando interno o externo,', 'programa o archivo por lotes ejecutable.']

# %%
type(directory)
# Out:
# IPython.utils.text.SList

# %%
message = "hello from Python"

# %%
# !echo {message}
# Out:
# hello from Python

# %% [markdown]
# ##### Shell-Related Magic Commands

# %%
# !cd
# Out:
# C:\Users\Cielo Aholiva\Documents\Ciencia de datos\Books

# %%
# %cd
# Out:
# C:\Users\Cielo Aholiva

# %%
cd myproject.txt
# Out:
# [WinError 2] El sistema no puede encontrar el archivo especificado: 'myproject.txt'
# C:\Users\Cielo Aholiva

# %%
mkdir tmp

# %%
ls tmp
# Out:
#  El volumen de la unidad C es Windows
#  El número de serie del volumen es: 7EFE-43C1
#
#  Directorio de C:\Users\Cielo Aholiva\tmp
#
# 05/09/2024  06:20 p. m.    <DIR>          .
# 05/09/2024  06:20 p. m.    <DIR>          ..
#                0 archivos              0 bytes
#                2 dirs  34,827,108,352 bytes libres

# %% [markdown]
# ### Chapter 3: Debugging and Profiling

# %% [markdown]
# ##### Controlling Exceptions: %xmode

# %%
a = 5
b = 7

# %%
def func1(a, b):
    return a / b
def func2(x):
    a = x
    b = x-1
    return func1(a, b)

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[567], line 1
# ----> 1 func2(1)
#
# Cell In[565], line 6, in func2(x)
#       4 a = x
#       5 b = x-1
# ----> 6 return func1(a, b)
#
# Cell In[565], line 2, in func1(a, b)
#       1 def func1(a, b):
# ----> 2     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %xmode Plain
# Out:
# Exception reporting mode: Plain

# %%
func2(1)
# Out:
# Traceback (most recent call last):
#
#   Cell In[573], line 1
#     func2(1)
#
#   Cell In[565], line 6 in func2
#     return func1(a, b)
#
#   Cell In[565], line 2 in func1
#     return a / b
#
# ZeroDivisionError: division by zero

# %%
# %xmode Verbose
# Out:
# Exception reporting mode: Verbose

# %%
func2(1)
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[577], line 1
# ----> 1 func2(1)
#
# Cell In[565], line 6, in func2(x=1)
#       4 a = x
#       5 b = x-1
# ----> 6 return func1(a, b)
#         a = 1
#         b = 0
#
# Cell In[565], line 2, in func1(a=1, b=0)
#       1 def func1(a, b):
# ----> 2     return a / b
#         a = 1
#         b = 0
#
# ZeroDivisionError: division by zero

# %% [markdown]
# ##### Debugging: When Reading Tracebacks Is Not Enough

# %%
# %xmode Plain
# %pdb on
func2(1)
# Out:
# Exception reporting mode: Plain
# Automatic pdb calling has been turned ON
# Traceback (most recent call last):
#
#   Cell In[602], line 3
#     func2(1)
#
#   Cell In[565], line 6 in func2
#     return func1(a, b)
#
#   Cell In[600], line 3 in func1
#     return a / b
#
# ZeroDivisionError: division by zero
# > c:\users\cielo aholiva\appdata\local\temp\ipykernel_18988\2963771293.py(3)func1()
# ipdb>  4
# 4
# ipdb>  7
# 7
# ipdb>  9
# 9
# ipdb>  7
# 7
# ipdb>  exit

# %% [markdown]
# ##### Profiling and Timing Code

# %%
% time #Time the execution of a single statement

# %%
# %timeit #Time repeated execution of a single statement for more accuracy

# %%
# %prun #Run code with the profiler

# %%
# %lprun #Run code with the line-by-line profiler

# %%
# %memit #Measure the memory use of a single statement

# %%
# %mprun #Run code with the line-by-line memory profiler

# %% [markdown]
# ##### Timing Code Snippets: %timeit and %time

# %%
# %timeit sum(range(100))
# Out:
# 1.32 μs ± 67.9 ns per loop (mean ± std. dev. of 7 runs, 1,000,000 loops each)

# %%
# %%timeit 
total = 0
for i in range(1000):
    for j in range(1000):
        total += i * (-1) ** j
# Out:
# 342 ms ± 19.9 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
import random
L = [random.random() for i in range(100000)]
# %timeit L.sort()
# Out:
# The slowest run took 4.28 times longer than the fastest. This could mean that an intermediate result is being cached.
# 2.54 ms ± 1.32 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
print("sorting an already sorted list:")
# %time L.sort()
# Out:
# sorting an already sorted list:
# CPU times: total: 0 ns
# Wall time: 16.1 ms

# %% [markdown]
# ##### Profiling Memory Use: %Memit and %mprun

# %%
# %load_ext memory_profiler
# Out:
# Traceback (most recent call last):
#
#   Cell In[623], line 1
#     get_ipython().run_line_magic('load_ext', 'memory_profiler')
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\site-packages\IPython\core\interactiveshell.py:2480 in run_line_magic
#     result = fn(*args, **kwargs)
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\site-packages\IPython\core\magics\extension.py:33 in load_ext
#     res = self.shell.extension_manager.load_extension(module_str)
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\site-packages\IPython\core\extensions.py:62 in load_extension
#     return self._load_extension(module_str)
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\site-packages\IPython\core\extensions.py:77 in _load_extension
#     mod = import_module(module_str)
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\importlib\__init__.py:90 in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#
# ...

# %%
# %memit sum_of_lists(1000000)
# Out:
# UsageError: Line magic function `%memit` not found.

# %%
# %%file mprun_demo.py
def sum_of_lists(N):
    total = 0
    for i in range(5):
        L = [j ^ (j >> i) for j in range(N)]
        total += sum(L)
        del L # remove reference to L
return total
# Out:
# Overwriting mprun_demo.py

# %%
from mprun_demo import sum_of_lists
# Out:
# Traceback (most recent call last):
#
#   File D:\Documentos\PHYTON\Phyton programa\1 CSharp\Lib\site-packages\IPython\core\interactiveshell.py:3577 in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#
#   Cell In[633], line 1
#     from mprun_demo import sum_of_lists
#
#   File ~\mprun_demo.py:7
#     return total
#     ^
# SyntaxError: 'return' outside function
